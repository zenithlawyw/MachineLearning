# %% [markdown]
# # Models of Stock Return

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ms = pd.read_csv('../data/stocks/microsoft.csv', index_col="Date")
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-12-31  46.730000  47.439999  46.450001  46.450001  42.848763  21552500
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  43.134731  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  42.738068  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  42.110783  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  42.645817  29114100

# %% [markdown]
# # Distribution of Log Return

# %%
ms['LogReturn'] = np.log(ms['Close']).shift(-1) - np.log(ms['Close'])

# %% [markdown]
# ### plot a histogram to show the distribution of the log return of the stock (expected to be very close to a normal distribution)

# %%
from scipy.stats import norm
mu = ms['LogReturn'].mean()
sigma = ms['LogReturn'].std(ddof=1)

density = pd.DataFrame()
density['x'] = np.arange(ms['LogReturn'].min()-0.01, ms['LogReturn'].max()+0.01, 0.001)
density['pdf'] = norm.pdf(density['x'], mu, sigma)

ms['LogReturn'].hist(bins=50, figsize=(15, 8))
plt.plot(density['x'], density['pdf'], color='red')
plt.show()

# %% [markdown]
# ### Calculate the probability of the stock price will drop over a certain percentage in a day

# %%
prob_return1 = norm.cdf(-0.05, mu, sigma)
print('Probability that the stock price will drop over 5% in a day is', prob_return1)
# Out:
# Probability that the stock price will drop over 5% in a day is 0.00017118482608677866

# %%
prob_return1 = norm.cdf(-0.1, mu, sigma)
print('Probability that the stock price will drop over 10% in a day is', prob_return1)
# Out:
# Probability that the stock price will drop over 10% in a day is 6.056775634858584e-13

# %% [markdown]
# ### Calculate the probability of the stock price will drop over a certain percentage in a year

# %%
# drop over 40% in 220 days
mu220 = 220*mu
sigma220 = (220**0.5) * sigma
print('The probability of dropping over 40% in 220 days is', norm.cdf(-0.4, mu220, sigma220))
# Out:
# The probability of dropping over 40% in 220 days is 0.0029123633133305506

# %%
# drop over 20% in 220 days
mu220 = 220*mu
sigma220 = (220**0.5) * sigma
drop20 = norm.cdf(-0.2, mu220, sigma220)
print('The probability of dropping over 20% in 220 days is', drop20)
# Out:
# The probability of dropping over 20% in 220 days is 0.03535237727490914

# %% [markdown]
# # Calculate Value at Risk (VaR)

# %%
VaR = norm.ppf(0.05, mu, sigma)
print('Single day value at risk ', VaR)
# Out:
# Single day value at risk  -0.02252336240706501

# %%
# 5% quantile
print('5% quantile ', norm.ppf(0.05, mu, sigma))
# 95% quantile
print('95% quantile ', norm.ppf(0.95, mu, sigma))
# Out:
# 5% quantile  -0.02252336240706501
# 95% quantile  0.02416382537931104

# %%
# 25% quantile
q25 = norm.ppf(0.25, mu, sigma)
print('25% quantile ', q25)
# 75% quantile
q75 = norm.ppf(0.75, mu, sigma)
print('75% quantile ', q75)
# Out:
# 25% quantile  -0.008752057838414963
# 75% quantile  0.01039252081066101
