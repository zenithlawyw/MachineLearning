# %% [markdown]
# # Population and Sample

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# *create a population dataframe with 10 data*

# %%
data = pd.DataFrame()
data['Population'] = [47, 48, 85, 20, 19, 13, 72, 16, 50, 60]

# %% [markdown]
# *draw sample with replacement; size = 5 from the population*

# %%
# Draw sample with replacement, size=5 from Population
a_sample_with_replacement = data['Population'].sample(5, replace=True)
print(a_sample_with_replacement)
# Out:
# 6    72
# 4    19
# 1    48
# 6    72
# 2    85
# Name: Population, dtype: int64

# %% [markdown]
# *draw sample without replacement; size = 5 from the population*

# %%
# Draw sample without replacement, size=5 from Population
a_sample_without_replacement = data['Population'].sample(5, replace=False)
print(a_sample_without_replacement)
# Out:
# 7    16
# 9    60
# 8    50
# 1    48
# 0    47
# Name: Population, dtype: int64

# %% [markdown]
# # Parameters and Statistics

# %% [markdown]
# ### Population Mean and Population Variance

# %%
population_mean = data['Population'].mean()
population_var = data['Population'].var(ddof=0)
print('Population mean is ', population_mean)
print('Population variance is', population_var)
# Out:
# Population mean is  43.0
# Population variance is 571.8

# %% [markdown]
# ### Sample Mean and Sample Variance (sample size = 10; with replacement)

# %%
a_sample = data['Population'].sample(10, replace=True)
sample_mean = a_sample.mean()
sample_var = a_sample.var()
print('Sample mean is ', sample_mean)
print('Sample variance is', sample_var)
# Out:
# Sample mean is  56.3
# Sample variance is 670.4555555555555

# %% [markdown]
# # Average of an unbiased estimator

# %%
sample_length = 500
sample_variance_collection=[data['Population'].sample(10, replace=True).var(ddof=1) for i in range(sample_length)]
print(sample_variance_collection)
# Out:
# [646.7111111111112, 428.67777777777775, 773.1222222222223, 235.1222222222222, 541.5666666666667, 408.6777777777778, 805.9555555555556, 250.9888888888889, 430.4, 540.9333333333333, 253.15555555555557, 681.7888888888888, 420.26666666666665, 452.40000000000003, 305.21111111111105, 627.5555555555555, 612.1777777777778, 546.7111111111112, 551.4333333333333, 752.2666666666668, 529.5111111111112, 540.4555555555555, 962.9444444444445, 996.9000000000001, 523.0666666666666, 431.5666666666666, 605.5111111111112, 636.2333333333332, 416.94444444444446, 979.2111111111112, 868.9000000000001, 637.7333333333332, 530.4555555555555, 615.9555555555556, 629.5666666666667, 713.5999999999999, 640.5444444444445, 412.4888888888889, 779.9555555555556, 518.9, 651.7333333333332, 713.1555555555556, 983.6111111111111, 529.5111111111112, 436.4, 761.0666666666667, 322.67777777777775, 910.2333333333333, 761.1555555555556, 671.6000000000001, 502.40000000000003, 448.23333333333335, 630.5444444444444, 520.7666666666668, 976.3999999999999, 720.4555555555556, 743.8777777777777, 574.4000000000001, 489.87777777777774, 388.6666666666667, 437.0666666666666, 581.6555555555556, 228.88888888888889, 556.1777777777778,